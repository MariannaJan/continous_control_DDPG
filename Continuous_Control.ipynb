# %% [markdown]
# # Continuous Control
#
# ---
#
# You are welcome to use this coding environment to train your agent for the project.  Follow the instructions below to get started!
#
# ### 1. Start the Environment
#
# Run the next code cell to install a few packages.  This line will take a few minutes to run!

# %%
# !pip -q install ./python
# Out:
# tensorflow 1.7.1 has requirement numpy>=1.13.3, but you'll have numpy 1.12.1 which is incompatible.
# ipython 6.5.0 has requirement prompt-toolkit<2.0.0,>=1.0.15, but you'll have prompt-toolkit 2.0.10 which is incompatible.

# %% [markdown]
# The environments corresponding to both versions of the environment are already saved in the Workspace and can be accessed at the file paths provided below.
#
# Please select one of the two options below for loading the environment.

# %%
from unityagents import UnityEnvironment
import numpy as np

# select this option to load version 1 (with a single agent) of the environment
env = UnityEnvironment(file_name='/data/Reacher_One_Linux_NoVis/Reacher_One_Linux_NoVis.x86_64')

# select this option to load version 2 (with 20 agents) of the environment
# env = UnityEnvironment(file_name='/data/Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 1
# Size of each action: 4
# There are 1 agents. Each observes a state with length: 33
# The state for the first agent looks like: [  0.00000000e+00  -4.00000000e+00   0.00000000e+00   1.00000000e+00
#   -0.00000000e+00  -0.00000000e+00  -4.37113883e-08   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00  -1.00000000e+01   0.00000000e+00
#    1.00000000e+00  -0.00000000e+00  -0.00000000e+00  -4.37113883e-08
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   5.75471878e+00  -1.00000000e+00
#    5.55726671e+00   0.00000000e+00   1.00000000e+00   0.00000000e+00
#   -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Note that **in this coding environment, you will not be able to watch the agents while they are training**, and you should set `train_mode=True` to restart the environment.

# %%
env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
# Out:
# Total score (averaged over agents) this episode: 0.0

# %% [markdown]
# When finished, you can close the environment.

# %%
#env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  A few **important notes**:
# - When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```
# - To structure your work, you're welcome to work directly in this Jupyter notebook, or you might like to start over with a new file!  You can see the list of files in the workspace by clicking on **_Jupyter_** in the top left corner of the notebook.
# - In this coding environment, you will not be able to watch the agents while they are training.  However, **_after training the agents_**, you can download the saved model weights to watch the agents on your own machine!

# %% [markdown]
# ### 5. Training the agent

# %%
SEED = 42

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import random
import torch

from collections import deque
from ddpg_agent import Agent
from unityagents import UnityEnvironment

from workspace_utils import active_session  #to keep the Udacity workspace awake

# %% [markdown]
# #### 5.1 Defining the DDPG function

# %%
def ddpg(n_episodes=2500, max_t=1000, print_every=1):
    """Deep Deterministic Policy Gradient (DDPG)
    
    Params
    ======
        n_episodes  (int)   : maximum number of training episodes
        max_t       (int)   : maximum number of timesteps per episode
        print_every (int)   : interval to display results

    """
    mean_scores = []                               # list of mean scores from each episode
    moving_avgs = []                               # list of moving averages
    best_score  = -np.inf
    scores_window = deque(maxlen=100)              # mean scores from most recent 100 episodes
    
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]       # reset environment
        states = env_info.vector_observations                   # get current state for each agent      
        scores = np.zeros(num_agents)                           # initialize score for each agent
        agent.reset()
        for t in range(max_t):
            actions = agent.act(states, add_noise=True)         # select an action
            env_info = env.step(actions)[brain_name]            # send actions to environment
            next_states = env_info.vector_observations          # get next state
            rewards = env_info.rewards                          # get reward
            dones = env_info.local_done                         # see if episode has finished
            # save experience to replay buffer, perform learning step at defined interval
            for state, action, reward, next_state, done in zip(states, actions, rewards, next_states, dones):
                agent.step(state, action, reward, next_state, done, t)             
            states = next_states
            scores += rewards        
            if np.any(dones):                                   # exit loop when episode ends
                break

        mean_scores.append(np.mean(scores))           # save mean score for the episode
        scores_window.append(mean_scores[-1])         # save mean score to window
        moving_avgs.append(np.mean(scores_window))    # save moving average
                
        if i_episode % print_every == 0:
            print('\rEpisode {} Mean: {:.1f}\tMoving Avg: {:.1f}'.format(\
                  i_episode, mean_scores[-1], moving_avgs[-1]))
                  
        if moving_avgs[-1] >= 30.00 and i_episode >= 100:
            # save the model weights for actor and critic networks
            torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')   
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode-100, moving_avgs[-1]))            
            break
            
    return mean_scores, moving_avgs

# %% [markdown]
# #### 5.2 Runnig the training of the agent

# %%
with active_session():
    agent = Agent(state_size=state_size, action_size=action_size, random_seed=SEED)
    scores, avgs = ddpg()
# Out:
# Episode 1 Mean: 0.0	Moving Avg: 0.0
# Episode 2 Mean: 0.6	Moving Avg: 0.3
# Episode 3 Mean: 0.0	Moving Avg: 0.2
# Episode 4 Mean: 0.0	Moving Avg: 0.2
# Episode 5 Mean: 0.5	Moving Avg: 0.3
# Episode 6 Mean: 0.3	Moving Avg: 0.3
# Episode 7 Mean: 0.3	Moving Avg: 0.3
# Episode 8 Mean: 0.6	Moving Avg: 0.3
# Episode 9 Mean: 1.0	Moving Avg: 0.4
# Episode 10 Mean: 0.2	Moving Avg: 0.4
# Episode 11 Mean: 1.5	Moving Avg: 0.5
# Episode 12 Mean: 2.5	Moving Avg: 0.6
# Episode 13 Mean: 0.1	Moving Avg: 0.6
# Episode 14 Mean: 0.4	Moving Avg: 0.6
# Episode 15 Mean: 0.0	Moving Avg: 0.6
# Episode 16 Mean: 0.3	Moving Avg: 0.5
# Episode 17 Mean: 0.4	Moving Avg: 0.5
# Episode 18 Mean: 1.3	Moving Avg: 0.6
# Episode 19 Mean: 0.9	Moving Avg: 0.6
# Episode 20 Mean: 1.2	Moving Avg: 0.6
# Episode 21 Mean: 0.3	Moving Avg: 0.6
# Episode 22 Mean: 1.4	Moving Avg: 0.6
# Episode 23 Mean: 0.7	Moving Avg: 0.6
# Episode 24 Mean: 0.6	Moving Avg: 0.6
# Episode 25 Mean: 1.7	Moving Avg: 0.7
# Episode 26 Mean: 0.3	Moving Avg: 0.7
# Episode 27 Mean: 0.1	Moving Avg: 0.6
# Episode 28 Mean: 0.6	Moving Avg: 0.6
# Episode 29 Mean: 0.5	Moving Avg: 0.6
# Episode 30 Mean: 0.2	Moving Avg: 0.6
# Episode 31 Mean: 0.7	Moving Avg: 0.6
# Episode 32 Mean: 1.1	Moving Avg: 0.6
# Episode 33 Mean: 2.7	Moving Avg: 0.7
# Episode 34 Mean: 2.4	Moving Avg: 0.8
# Episode 35 Mean: 3.0	Moving Avg: 0.8
# Episode 36 Mean: 2.9	Moving Avg: 0.9
# Episode 37 Mean: 1.5	Moving Avg: 0.9
# Episode 38 Mean: 1.1	Moving Avg: 0.9
# Episode 39 Mean: 1.8	Moving Avg: 0.9
# Episode 40 Mean: 2.0	Moving Avg: 1.0
# Episode 41 Mean: 2.0	Moving Avg: 1.0
# Episode 42 Mean: 1.6	Moving Avg: 1.0
# Episode 43 Mean: 1.0	Moving Avg: 1.0
# Episode 44 Mean: 1.3	Moving Avg: 1.0
# Episode 45 Mean: 1.5	Moving Avg: 1.0
# Episode 46 Mean: 2.7	Moving Avg: 1.0
# Episode 47 Mean: 2.0	Moving Avg: 1.1
# Episode 48 Mean: 1.7	Moving Avg: 1.1
# Episode 49 Mean: 1.9	Moving Avg: 1.1
# Episode 50 Mean: 1.6	Moving Avg: 1.1
# Episode 51 Mean: 2.7	Moving Avg: 1.1
# Episode 52 Mean: 1.8	Moving Avg: 1.1
# Episode 53 Mean: 0.8	Moving Avg: 1.1
# Episode 54 Mean: 2.4	Moving Avg: 1.2
# Episode 55 Mean: 1.1	Moving Avg: 1.2
# Episode 56 Mean: 3.7	Moving Avg: 1.2
# Episode 57 Mean: 1.0	Moving Avg: 1.2
# Episode 58 Mean: 2.9	Moving Avg: 1.2
# Episode 59 Mean: 1.5	Moving Avg: 1.2
# Episode 60 Mean: 0.7	Moving Avg: 1.2
# Episode 61 Mean: 1.4	Moving Avg: 1.2
# Episode 62 Mean: 2.6	Moving Avg: 1.3
# Episode 63 Mean: 0.8	Moving Avg: 1.3
# Episode 64 Mean: 1.5	Moving Avg: 1.3
# Episode 65 Mean: 2.5	Moving Avg: 1.3
# Episode 66 Mean: 2.1	Moving Avg: 1.3
# Episode 67 Mean: 1.9	Moving Avg: 1.3
# Episode 68 Mean: 1.7	Moving Avg: 1.3
# Episode 69 Mean: 2.9	Moving Avg: 1.3
# Episode 70 Mean: 1.6	Moving Avg: 1.3
# Episode 71 Mean: 1.4	Moving Avg: 1.3
# Episode 72 Mean: 2.1	Moving Avg: 1.3
# Episode 73 Mean: 1.1	Moving Avg: 1.3
# Episode 74 Mean: 2.0	Moving Avg: 1.3
# Episode 75 Mean: 2.3	Moving Avg: 1.4
# Episode 76 Mean: 2.5	Moving Avg: 1.4
# Episode 77 Mean: 1.4	Moving Avg: 1.4
# Episode 78 Mean: 2.8	Moving Avg: 1.4
# Episode 79 Mean: 2.6	Moving Avg: 1.4
# Episode 80 Mean: 2.0	Moving Avg: 1.4
# Episode 81 Mean: 3.1	Moving Avg: 1.4
# Episode 82 Mean: 2.2	Moving Avg: 1.4
# Episode 83 Mean: 1.0	Moving Avg: 1.4
# Episode 84 Mean: 0.8	Moving Avg: 1.4
# Episode 85 Mean: 1.6	Moving Avg: 1.4
# Episode 86 Mean: 1.1	Moving Avg: 1.4
# Episode 87 Mean: 1.1	Moving Avg: 1.4
# Episode 88 Mean: 0.8	Moving Avg: 1.4
# Episode 89 Mean: 1.5	Moving Avg: 1.4
# Episode 90 Mean: 10.1	Moving Avg: 1.5
# Episode 91 Mean: 2.2	Moving Avg: 1.5
# Episode 92 Mean: 4.9	Moving Avg: 1.6
# Episode 93 Mean: 2.3	Moving Avg: 1.6
# Episode 94 Mean: 2.6	Moving Avg: 1.6
# Episode 95 Mean: 1.8	Moving Avg: 1.6
# Episode 96 Mean: 1.7	Moving Avg: 1.6
# Episode 97 Mean: 1.3	Moving Avg: 1.6
# Episode 98 Mean: 2.6	Moving Avg: 1.6
# Episode 99 Mean: 4.7	Moving Avg: 1.6
# Episode 100 Mean: 3.4	Moving Avg: 1.6
# Episode 101 Mean: 1.9	Moving Avg: 1.7
# Episode 102 Mean: 3.0	Moving Avg: 1.7
# Episode 103 Mean: 4.0	Moving Avg: 1.7
# Episode 104 Mean: 4.1	Moving Avg: 1.8
# Episode 105 Mean: 1.8	Moving Avg: 1.8
# Episode 106 Mean: 4.8	Moving Avg: 1.8
# Episode 107 Mean: 2.0	Moving Avg: 1.8
# Episode 108 Mean: 2.2	Moving Avg: 1.9
# Episode 109 Mean: 4.8	Moving Avg: 1.9
# Episode 110 Mean: 3.2	Moving Avg: 1.9
# Episode 111 Mean: 3.6	Moving Avg: 1.9
# Episode 112 Mean: 3.5	Moving Avg: 2.0
# Episode 113 Mean: 3.5	Moving Avg: 2.0
# Episode 114 Mean: 4.5	Moving Avg: 2.0
# Episode 115 Mean: 2.7	Moving Avg: 2.1
# Episode 116 Mean: 4.0	Moving Avg: 2.1
# Episode 117 Mean: 3.8	Moving Avg: 2.1
# Episode 118 Mean: 5.2	Moving Avg: 2.2
# Episode 119 Mean: 5.8	Moving Avg: 2.2
# Episode 120 Mean: 2.5	Moving Avg: 2.2
# Episode 121 Mean: 5.4	Moving Avg: 2.3
# Episode 122 Mean: 5.1	Moving Avg: 2.3
# Episode 123 Mean: 5.2	Moving Avg: 2.4
# Episode 124 Mean: 4.0	Moving Avg: 2.4
# Episode 125 Mean: 3.2	Moving Avg: 2.4
# Episode 126 Mean: 3.0	Moving Avg: 2.4
# Episode 127 Mean: 5.0	Moving Avg: 2.5
# Episode 128 Mean: 2.4	Moving Avg: 2.5
# Episode 129 Mean: 2.4	Moving Avg: 2.5
# Episode 130 Mean: 3.7	Moving Avg: 2.6
# Episode 131 Mean: 2.9	Moving Avg: 2.6
# Episode 132 Mean: 9.1	Moving Avg: 2.7
# Episode 133 Mean: 5.0	Moving Avg: 2.7
# Episode 134 Mean: 2.0	Moving Avg: 2.7
# Episode 135 Mean: 5.1	Moving Avg: 2.7
# Episode 136 Mean: 2.9	Moving Avg: 2.7
# Episode 137 Mean: 3.7	Moving Avg: 2.7
# Episode 138 Mean: 2.6	Moving Avg: 2.7
# Episode 139 Mean: 3.9	Moving Avg: 2.8
# Episode 140 Mean: 4.9	Moving Avg: 2.8
# Episode 141 Mean: 5.3	Moving Avg: 2.8
# Episode 142 Mean: 0.6	Moving Avg: 2.8
# Episode 143 Mean: 3.6	Moving Avg: 2.8
# Episode 144 Mean: 3.3	Moving Avg: 2.9
# Episode 145 Mean: 3.6	Moving Avg: 2.9
# Episode 146 Mean: 5.4	Moving Avg: 2.9
# Episode 147 Mean: 6.3	Moving Avg: 2.9
# Episode 148 Mean: 5.8	Moving Avg: 3.0
# Episode 149 Mean: 4.0	Moving Avg: 3.0
# Episode 150 Mean: 3.7	Moving Avg: 3.0
# Episode 151 Mean: 5.7	Moving Avg: 3.1
# Episode 152 Mean: 4.6	Moving Avg: 3.1
# Episode 153 Mean: 2.5	Moving Avg: 3.1
# Episode 154 Mean: 6.8	Moving Avg: 3.2
# Episode 155 Mean: 3.2	Moving Avg: 3.2
# Episode 156 Mean: 4.6	Moving Avg: 3.2
# Episode 157 Mean: 5.9	Moving Avg: 3.2
# Episode 158 Mean: 14.1	Moving Avg: 3.3
# Episode 159 Mean: 7.2	Moving Avg: 3.4
# Episode 548 Mean: 18.3	Moving Avg: 13.7
# Episode 549 Mean: 12.4	Moving Avg: 13.8
# Episode 550 Mean: 17.5	Moving Avg: 13.8
# Episode 551 Mean: 14.5	Moving Avg: 13.9
# Episode 552 Mean: 12.1	Moving Avg: 13.9
# Episode 553 Mean: 11.7	Moving Avg: 13.9
# Episode 554 Mean: 17.8	Moving Avg: 13.9
# Episode 555 Mean: 11.6	Moving Avg: 13.9
# Episode 556 Mean: 17.0	Moving Avg: 14.0
# Episode 557 Mean: 15.9	Moving Avg: 14.0
# Episode 558 Mean: 13.7	Moving Avg: 14.1
# Episode 559 Mean: 21.4	Moving Avg: 14.1
# Episode 560 Mean: 13.0	Moving Avg: 14.0
# Episode 561 Mean: 16.9	Moving Avg: 14.0
# Episode 562 Mean: 17.4	Moving Avg: 14.0
# Episode 563 Mean: 14.0	Moving Avg: 14.0
# Episode 564 Mean: 17.1	Moving Avg: 14.1
# Episode 565 Mean: 16.8	Moving Avg: 14.1
# Episode 566 Mean: 11.9	Moving Avg: 14.0
# Episode 567 Mean: 16.0	Moving Avg: 14.1
# Episode 568 Mean: 11.5	Moving Avg: 14.0
# Episode 569 Mean: 10.6	Moving Avg: 14.0
# Episode 570 Mean: 19.7	Moving Avg: 14.1
# Episode 571 Mean: 14.3	Moving Avg: 14.1
# Episode 572 Mean: 18.4	Moving Avg: 14.2
# Episode 573 Mean: 16.2	Moving Avg: 14.2
# Episode 574 Mean: 19.7	Moving Avg: 14.3
# Episode 575 Mean: 16.2	Moving Avg: 14.3
# Episode 576 Mean: 13.1	Moving Avg: 14.4
# Episode 577 Mean: 13.2	Moving Avg: 14.4
# Episode 578 Mean: 14.8	Moving Avg: 14.4
# Episode 579 Mean: 14.6	Moving Avg: 14.4
# Episode 580 Mean: 15.2	Moving Avg: 14.5
# Episode 581 Mean: 13.6	Moving Avg: 14.5
# Episode 582 Mean: 10.7	Moving Avg: 14.5
# Episode 583 Mean: 18.1	Moving Avg: 14.5
# Episode 584 Mean: 15.2	Moving Avg: 14.6
# Episode 585 Mean: 13.1	Moving Avg: 14.6
# Episode 586 Mean: 15.2	Moving Avg: 14.6
# Episode 587 Mean: 12.0	Moving Avg: 14.6
# Episode 588 Mean: 8.7	Moving Avg: 14.6
# Episode 589 Mean: 15.6	Moving Avg: 14.6
# Episode 590 Mean: 13.5	Moving Avg: 14.6
# Episode 591 Mean: 26.5	Moving Avg: 14.8
# Episode 592 Mean: 8.9	Moving Avg: 14.7
# Episode 593 Mean: 14.2	Moving Avg: 14.7
# Episode 594 Mean: 12.5	Moving Avg: 14.7
# Episode 595 Mean: 8.9	Moving Avg: 14.7
# Episode 596 Mean: 14.1	Moving Avg: 14.7
# Episode 597 Mean: 11.8	Moving Avg: 14.7
# Episode 598 Mean: 17.4	Moving Avg: 14.8
# Episode 599 Mean: 15.7	Moving Avg: 14.8
# Episode 600 Mean: 19.3	Moving Avg: 14.9
# Episode 601 Mean: 16.1	Moving Avg: 14.9
# Episode 602 Mean: 12.5	Moving Avg: 14.9
# Episode 880 Mean: 35.3	Moving Avg: 27.1
# Episode 881 Mean: 29.1	Moving Avg: 27.3
# Episode 882 Mean: 28.3	Moving Avg: 27.2
# Episode 883 Mean: 33.4	Moving Avg: 27.3
# Episode 884 Mean: 29.0	Moving Avg: 27.3
# Episode 885 Mean: 35.4	Moving Avg: 27.4
# Episode 886 Mean: 31.7	Moving Avg: 27.5
# Episode 887 Mean: 35.3	Moving Avg: 27.5
# Episode 888 Mean: 27.8	Moving Avg: 27.6
# Episode 889 Mean: 31.3	Moving Avg: 27.7
# Episode 890 Mean: 36.0	Moving Avg: 27.8
# Episode 891 Mean: 31.2	Moving Avg: 27.9
# Episode 892 Mean: 29.1	Moving Avg: 28.0
# Episode 893 Mean: 26.4	Moving Avg: 28.0
# Episode 894 Mean: 24.9	Moving Avg: 28.0
# Episode 895 Mean: 32.0	Moving Avg: 28.1
# Episode 896 Mean: 35.0	Moving Avg: 28.2
# Episode 897 Mean: 30.2	Moving Avg: 28.3
# Episode 898 Mean: 25.2	Moving Avg: 28.4
# Episode 899 Mean: 31.8	Moving Avg: 28.5
# Episode 900 Mean: 27.8	Moving Avg: 28.5
# Episode 901 Mean: 30.9	Moving Avg: 28.6
# Episode 902 Mean: 37.8	Moving Avg: 28.8
# Episode 903 Mean: 29.1	Moving Avg: 28.8
# Episode 904 Mean: 36.6	Moving Avg: 28.9
# Episode 905 Mean: 20.7	Moving Avg: 28.8
# Episode 906 Mean: 27.9	Moving Avg: 28.8
# Episode 907 Mean: 28.9	Moving Avg: 28.8
# Episode 908 Mean: 26.1	Moving Avg: 28.8
# Episode 909 Mean: 31.7	Moving Avg: 28.8
# Episode 910 Mean: 32.5	Moving Avg: 28.9
# Episode 911 Mean: 33.8	Moving Avg: 29.0
# Episode 912 Mean: 22.7	Moving Avg: 29.0
# Episode 913 Mean: 33.8	Moving Avg: 29.1
# Episode 914 Mean: 34.5	Moving Avg: 29.2
# Episode 915 Mean: 34.9	Moving Avg: 29.4
# Episode 916 Mean: 29.5	Moving Avg: 29.5
# Episode 917 Mean: 25.1	Moving Avg: 29.5
# Episode 918 Mean: 35.9	Moving Avg: 29.4
# Episode 919 Mean: 29.8	Moving Avg: 29.5
# Episode 920 Mean: 26.4	Moving Avg: 29.5
# Episode 921 Mean: 35.8	Moving Avg: 29.6
# Episode 922 Mean: 37.5	Moving Avg: 29.7
# Episode 923 Mean: 34.6	Moving Avg: 29.7
# Episode 924 Mean: 33.3	Moving Avg: 29.7
# Episode 925 Mean: 33.8	Moving Avg: 29.8
# Episode 926 Mean: 35.5	Moving Avg: 29.9
# Episode 927 Mean: 33.8	Moving Avg: 30.0
# Episode 928 Mean: 33.9	Moving Avg: 30.0
#
# Environment solved in 828 episodes!	Average Score: 30.04

# %% [markdown]
# #### 5.3 Plot of Rewards

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='DDPG')
plt.plot(np.arange(len(scores)), avgs, c='r', label='Moving AVG')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
